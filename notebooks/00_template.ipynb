# %% [markdown]
# # 00 · Template — <Name der Grafik>
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Padddoo/Tobys-Elegant-Graphics/blob/main/notebooks/00_template.ipynb)
#
# ---
#
# ## 1 · Die Frage
#
# *Welche analytische Frage beantwortet diese Grafik?*
#
# > **Beispiel (Histogramm):** Wie ist eine einzelne numerische Variable verteilt — symmetrisch, schief, mehrgipflig?
#
# **Wann nutzen:** <1–2 Sätze>
#
# **Wann NICHT nutzen:** <1–2 Sätze>

# %% [markdown]
# ## 2 · Setup & Daten laden
#
# Diese Zelle ist in allen Notebooks identisch — sie lädt den Datensatz direkt von GitHub,
# es ist kein lokales Setup nötig.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", context="notebook")

DATA_URL = (
    "https://raw.githubusercontent.com/Padddoo/Tobys-Elegant-Graphics/"
    "main/data/shipping_orders_2024.csv"
)

df = pd.read_csv(DATA_URL, parse_dates=["order_date"])
print(f"{len(df):,} Zeilen, {df.shape[1]} Spalten")
df.head()

# %% [markdown]
# ## 3 · Minimalbeispiel
#
# *Die Grafik in ihrer einfachsten Form — das Copy-Paste-Snippet für den Alltag (≤ 5 Zeilen).*

# %%
# TODO: Minimalbeispiel — z. B.
# sns.histplot(df["delivery_days"])
# plt.show()

# %% [markdown]
# ## 4 · Elegante Version
#
# *Beschriftet, aufgeräumt, präsentationstauglich. Diese Version landet als PNG in `images/`.*

# %%
fig, ax = plt.subplots(figsize=(9, 5))

# TODO: elegante Version der Grafik

ax.set_title("<Aussagekräftiger Titel: die Erkenntnis, nicht die Methode>")
ax.set_xlabel("<Achse mit Einheit>")
ax.set_ylabel("<Achse mit Einheit>")
sns.despine()
fig.tight_layout()

# Export für das Repo (nur lokal ausführen, in Colab auskommentiert lassen):
# fig.savefig("../images/00_template.png", dpi=150, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## 5 · Fallstricke & Trade-offs
#
# *Was zeigt die Grafik — und was verschweigt sie?*
#
# | Fallstrick | Warum es schiefgeht | Gegenmittel |
# |---|---|---|
# | <z. B. zu wenige Bins> | <verdeckt Mehrgipfligkeit> | <mehrere Bin-Breiten testen> |
# | … | … | … |

# %% [markdown]
# ## 6 · Varianten
#
# *1–2 sinnvolle Abwandlungen — wann lohnt sich welche?*

# %%
# TODO: Variante(n) — z. B. log-Skala, Normierung, Facetten

# %% [markdown]
# ## 7 · Übung
#
# *Eine offene Aufgabe am Datensatz — erst selbst probieren, dann Lösung aufklappen.*
#
# **Aufgabe:** <z. B. „Erstelle die Grafik für `order_value_eur` statt `delivery_days`. Was fällt auf?">

# %%
# Dein Code hier:

# %% [markdown]
# <details>
# <summary>💡 Lösung anzeigen</summary>
#
# ```python
# # TODO: Musterlösung
# ```
#
# <Aussage: Was sollte man in der Lösung erkennen?>
#
# </details>
